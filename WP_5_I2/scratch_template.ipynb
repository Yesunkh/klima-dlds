# %% [markdown]
# # Scratch — WP I2 — Is the difference real or chance?
# Copy/rename this file to `scratch_<yourname>.ipynb` and work here — not in the main file `klima_analyse.ipynb`.

# %%
import pandas as pd
df = pd.read_csv("../data/clean/temp_annual_regions.csv")
de = df[["jahr", "Deutschland"]].copy()   # main series for D1, I1, I2
df.head(3)

# %% [markdown]
# **Task:** Periods 1881–1950 vs. 1990–2025: bootstrap CI (10,000 resamples, seed 42) + Welch t-test + Cohen's d.
#
# Template: `projekt_schritte.md` Block 5. Save figures to `../figures/` as `fig4_*.png`.

# %%
# let's go
